# %%
solved_times = {
    "Vanilla_REINFORCE": 321,
    "REINFORCE_advantage": 183,
    "A2C": 272,
    "A2C_tn": 312,
    "PPO_eps_02": 91,
    "PPO_eps_07": 83,
    "PPO_eps_1": 167
}

episodes = {
    "Vanilla_REINFORCE": 234*10,
    "REINFORCE_advantage": 108*10,
    "A2C": 714,
    "A2C_tn": 410,
    "PPO_eps_02": 1750,
    "PPO_eps_07": 1270,
    "PPO_eps_1": 2411
}

opt_steps = {
    "Vanilla_REINFORCE": 234,
    "REINFORCE_advantage": 108,
    "A2C": 714*400/5,
    "A2C_tn": 410*400/5,
    "PPO_eps_02": 511,
    "PPO_eps_07": 425,
    "PPO_eps_1": 711
}

# %%
from matplotlib import pyplot as plt

# Order the dictionary by values (solved times) in descending order
ordered_solved_times = dict(sorted(solved_times.items(), key=lambda x: x[1], reverse=True))

# Extract the keys and values
algorithms = list(ordered_solved_times.keys())
times = list(ordered_solved_times.values())

# Create the bar chart
plt.figure(figsize=(10, 6))
plt.bar(algorithms, times, color='skyblue')

# Add title and labels
plt.title('Environment Solved Times for Different Algorithms')
plt.xlabel('Algorithms')
plt.ylabel('Time (seconds)')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Display the plot
plt.tight_layout()
plt.show()

# %%
from matplotlib import pyplot as plt

# Order the dictionary by values (solved times) in descending order
ordered_solved_times = dict(sorted(episodes.items(), key=lambda x: x[1], reverse=True))

# Extract the keys and values
algorithms = list(ordered_solved_times.keys())
times = list(ordered_solved_times.values())

# Create the bar chart
plt.figure(figsize=(10, 6))
plt.bar(algorithms, times, color='skyblue')

# Add title and labels
plt.title('Convergence episodes for Different Algorithms')
plt.xlabel('Algorithms')
plt.ylabel('Number of episodes')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Display the plot
plt.tight_layout()
plt.show()

# %%
from matplotlib import pyplot as plt

# Order the dictionary by values (solved times) in descending order
ordered_solved_times = dict(sorted(opt_steps.items(), key=lambda x: x[1], reverse=True))

# Extract the keys and values
algorithms = list(ordered_solved_times.keys())
times = list(ordered_solved_times.values())

# Create the bar chart
plt.figure(figsize=(10, 6))
plt.bar(algorithms, times, color='skyblue')

# Add title and labels
plt.title('Optimization steps for Different Algorithms')
plt.xlabel('Algorithms')
plt.ylabel('Optimization steps')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Display the plot
plt.tight_layout()
plt.show()

# %%
from matplotlib import pyplot as plt
import math

# Order the dictionary by values (solved times) in descending order
ordered_solved_times = dict(sorted(opt_steps.items(), key=lambda x: x[1], reverse=True))

# Extract the keys and values
algorithms = list(ordered_solved_times.keys())
times = list(ordered_solved_times.values())

times = [math.log10(time) for time in times]


# Create the bar chart
plt.figure(figsize=(10, 6))
plt.bar(algorithms, times, color='skyblue')

# Add title and labels
plt.title('log10(Optimization steps) for Different Algorithms')
plt.xlabel('Algorithms')
plt.ylabel('log10(Optimization steps)')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Display the plot
plt.tight_layout()
plt.show()
